# %% [markdown]
# # Graph for BFS and DFS:
# ![BFS-DFS.png](data:image/png;base64,...)

# %%
import networkx as nx
import matplotlib.pyplot as plt

graph = nx.DiGraph()

graph.add_nodes_from(['A', 'B', 'C', 'D', 'E', 'F'])
graph.add_edges_from([('A', 'B'), ('A', 'C'), ('A', 'D'), ('C', 'E'), ('C', 'F'), ('D', 'F')])

pos = nx.spring_layout(graph)
nx.draw(graph,pos,with_labels=True)
plt.show()

# %%
# Degree of nodes

print("Degree:", graph.degree())
print("In-degree:",graph.in_degree())
print("Out-degree:",graph.out_degree())
# Out:
# Degree: [('A', 3), ('B', 1), ('C', 3), ('D', 2), ('E', 1), ('F', 2)]
# In-degree: [('A', 0), ('B', 1), ('C', 1), ('D', 1), ('E', 1), ('F', 2)]
# Out-degree: [('A', 3), ('B', 0), ('C', 2), ('D', 1), ('E', 0), ('F', 0)]

# %% [markdown]
# # BFS

# %%
# BFS

def bfs(graph, start):
  visited = set()
  queue = [start]
  ans = []
  while queue:
    current = queue.pop(0)
    if current not in visited:
      visited.add(current)
      ans.append(current)
      queue.extend(graph.successors(current))
  return ans

print("BFS:",bfs(graph, 'A'))
# Out:
# BFS: ['A', 'B', 'C', 'D', 'E', 'F']

# %% [markdown]
# # DFS

# %%
# DFS
def dfs(graph, start):
  visited = set()
  stack = [start]
  ans = []
  while stack:
    node = stack.pop()
    if node not in visited:
      visited.add(node)
      ans.append(node)
      for neighbor in graph.neighbors(node):
        stack.append(neighbor)
  return ans

print("DFS:",dfs(graph, 'A'))
# Out:
# DFS: ['A', 'D', 'F', 'C', 'E', 'B']

# %%
# Density

density = nx.density(graph)
print("Density:", density)
# Out:
# Density: 0.2

# %%
# Reciprocity

reciprocity = nx.reciprocity(graph)
print("Reciprocity:",reciprocity)
# Out:
# Reciprocity: 0.0
